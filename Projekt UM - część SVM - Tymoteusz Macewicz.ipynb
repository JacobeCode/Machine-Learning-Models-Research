# %% [markdown]
# ## Projekt 1
#
# Klasyfikacja instrumentów za pomocą wektorów nośnych
#
# Problem badawczy, baza danych oraz sposób postępowania zgodne z tymi przedstawionymi w dokumentacji projektu

# %%
# Importing libraries

import scipy.stats
import os
import librosa
import pickle
import optuna
import pandas as pd

import numpy as np
import lightgbm as lgb
import matplotlib.pyplot as plt

from collections import Counter
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.metrics import roc_auc_score, roc_curve, auc, precision_recall_curve, accuracy_score, recall_score, precision_score, f1_score, make_scorer, confusion_matrix, log_loss
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.model_selection import cross_validate, StratifiedKFold
from pathlib import Path
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## 1. Preprocessing
#
# Wczytanie plików do data frame, przypisanie labeli odpowienim plikom reprezentującym dany instrument (klasę), wykestrahowanie 13 współczynników MFCC, zweryfikowanie czy wszystkie nagrania są zgodne co do długości, częstotliwości próbkowania, przeprowadzenie standaryzacji za pomocą Standard Scaler
#
# Oznaczenia klas:
# Cello (cel) - 0,
# Clarinet (cla) - 1,
# Flute (flu) - 2,
# Acoustic guitar (gac) - 3,
# Electric guitar (gel) - 4,
# Organ (org) - 5,
# Piano (pia) - 6,
# Saxophone (sax) - 7,
# Trumpet (tru) - 8,
# Violin (vio) - 9,
# Human singing voice (voi) - 10

# %%
# Loading and labeling data

file_names = []
file_data = []
labels = []
sampling_freqs = []

for directory in os.listdir("irmas"):
    for file in os.listdir(os.path.join(Path.cwd(),"irmas",directory)):
        file_names.append(file)
        y, sr = librosa.load(os.path.join(Path.cwd(),"irmas",directory,file), sr=44100)
        file_data.append(y)
        sampling_freqs.append(sr)
        if file.startswith('[cel]'):
            labels.append(0)
        if file.startswith('[cla]'):
            labels.append(1)
        if file.startswith('[flu]'):
            labels.append(2)
        if file.startswith('[gac]'):
            labels.append(3)            
        if file.startswith('[gel]'):
            labels.append(4)
        if file.startswith('[org]'):
            labels.append(5)            
        if file.startswith('[pia]'):
            labels.append(6)            
        if file.startswith('[sax]'):
            labels.append(7)            
        if file.startswith('[tru]'):
            labels.append(8)            
        if file.startswith('[vio]'):
            labels.append(9)            
        if file.startswith('[voi]'):
            labels.append(10)            
            
            
# Adding data to a dataframe
df = pd.DataFrame(columns=['file_name', 'file_data', 'sampling_frequency', 'label'])
df['file_name'] = file_names
df['file_data'] = file_data
df['sampling_frequency'] = sampling_freqs
df['label'] = labels

# %%
display(df)
# Out:
#                       file_name  \
# 0         [cel][cla]0001__1.wav
# 1         [cel][cla]0001__2.wav
# 2         [cel][cla]0001__3.wav
# 3         [cel][cla]0002__1.wav
# 4         [cel][cla]0002__2.wav
# ...                         ...
# 1555  [voi][pop_roc]2546__3.wav
# 1556  [voi][pop_roc]2547__1.wav
# 1557  [voi][pop_roc]2547__2.wav
# 1558  [voi][pop_roc]2547__3.wav
# 1559  [voi][pop_roc]2548__1.wav
#
#                                               file_data  sampling_frequency  \
# 0     [0.022232056, 0.02468872, 0.02645874, 0.027236...               44100
# 1     [-0.0033721924, -0.003967285, -0.003479004, -0...               44100
# 2     [0.00061035156, 0.0001373291, -0.0005950928, -...               44100
# 3     [-0.00024414062, -0.0013885498, -0.0026397705,...               44100
# 4     [-0.00018310547, 0.00076293945, 0.0011901855, ...               44100
# ...                                                 ...                 ...
# 1555  [0.0059509277, 0.015350342, 0.023391724, 0.032...               44100
# 1556  [-0.11528015, -0.15473938, -0.15000916, -0.113...               44100
# 1557  [0.1661377, 0.15690613, 0.12338257, 0.07142639...               44100
# 1558  [0.14439392, 0.12376404, 0.10206604, 0.0853881...               44100
# 1559  [0.009460449, -0.008239746, -0.022598267, -0.0...               44100
#
#       label
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ...     ...
# 1555     10
# 1556     10
# 1557     10
# 1558     10
# 1559     10
#
# [1560 rows x 4 columns]

# %% [markdown]
# Wszystkie dane mają tą samą długość oraz częstotliwość próbkowania (sprawdzane przy drugim modelu)

# %%
# Extracting MFCC Coefficients

mfccs = []
mfccs_delta = []
mfccs_deltasq = []

for data in df["file_data"]:
    mfcc = librosa.feature.mfcc(y=data, sr=22050, n_mfcc=13).flatten()
    mfccs.append(mfcc)
    mfccs_delta.append(librosa.feature.delta(mfcc))
    mfccs_deltasq.append(librosa.feature.delta(mfcc, order=2))
                 
               
df['mfcc'] = mfccs
df['mfcc_delta'] = mfccs_delta
df['mfcc_delta_sq'] = mfccs_deltasq

# %%
display(df)
# Out:
#                       file_name  \
# 0         [cel][cla]0001__1.wav
# 1         [cel][cla]0001__2.wav
# 2         [cel][cla]0001__3.wav
# 3         [cel][cla]0002__1.wav
# 4         [cel][cla]0002__2.wav
# ...                         ...
# 1555  [voi][pop_roc]2546__3.wav
# 1556  [voi][pop_roc]2547__1.wav
# 1557  [voi][pop_roc]2547__2.wav
# 1558  [voi][pop_roc]2547__3.wav
# 1559  [voi][pop_roc]2548__1.wav
#
#                                               file_data  sampling_frequency  \
# 0     [0.022232056, 0.02468872, 0.02645874, 0.027236...               44100
# 1     [-0.0033721924, -0.003967285, -0.003479004, -0...               44100
# 2     [0.00061035156, 0.0001373291, -0.0005950928, -...               44100
# 3     [-0.00024414062, -0.0013885498, -0.0026397705,...               44100
# 4     [-0.00018310547, 0.00076293945, 0.0011901855, ...               44100
# ...                                                 ...                 ...
# 1555  [0.0059509277, 0.015350342, 0.023391724, 0.032...               44100
# 1556  [-0.11528015, -0.15473938, -0.15000916, -0.113...               44100
# 1557  [0.1661377, 0.15690613, 0.12338257, 0.07142639...               44100
# 1558  [0.14439392, 0.12376404, 0.10206604, 0.0853881...               44100
# 1559  [0.009460449, -0.008239746, -0.022598267, -0.0...               44100
#
#       label                                               mfcc  \
# 0         0  [-452.01215, -463.70468, -473.78613, -472.0447...
# 1         0  [-353.5875, -345.70627, -341.9458, -340.2455, ...
# 2         0  [-426.93094, -434.9382, -442.07135, -440.38293...
# 3         0  [-465.59283, -472.84494, -483.94357, -485.5826...
# 4         0  [-464.96738, -462.2898, -464.4726, -464.46667,...
# ...     ...                                                ...
# 1555     10  [-178.58676, -172.2699, -171.96695, -177.94272...
# 1556     10  [-127.25734, -122.60771, -121.361145, -122.555...
# 1557     10  [-134.16048, -133.197, -144.1307, -150.18326, ...
# 1558     10  [-119.69623, -61.883232, -53.847103, -72.93917...
# 1559     10  [-133.41035, -132.13742, -129.30109, -133.6045...
#
#                                              mfcc_delta  \
# 0     [-1.9220424, -1.9220424, -1.9220424, -1.922042...
# 1     [1.5634588, 1.5634588, 1.5634588, 1.5634588, 1...
# 2     [0.46890718, 0.46890718, 0.46890718, 0.4689071...
# 3     [-0.92114764, -0.92114764, -0.92114764, -0.921...
# 4     [-0.2734192, -0.2734192, -0.2734192, -0.273419...
# ...                                                 ...
# 1555  [-3.9553516, -3.9553516, -3.9553516, -3.955351...
# 1556  [-1.1543529, -1.1543529, -1.1543529, -1.154352...
# 1557  [11.054637, 11.054637, 11.054637, 11.054637, 1...
# 1558  [-2.1233065, -2.1233065, -2.1233065, -2.123306...
# 1559  [-0.738473, -0.738473, -0.738473, -0.738473, -...
#
#                                           mfcc_delta_sq
# 0     [0.7014014, 0.7014014, 0.7014014, 0.7014014, 0...
# 1     [-1.1336648, -1.1336648, -1.1336648, -1.133664...
# 2     [1.7306954, 1.7306954, 1.7306954, 1.7306954, 1...
# 3     [1.5679516, 1.5679516, 1.5679516, 1.5679516, 1...
# 4     [-0.3988473, -0.3988473, -0.3988473, -0.398847...
# ...                                                 ...
# 1555  [-1.0631608, -1.0631608, -1.0631608, -1.063160...
# 1556  [-0.72465014, -0.72465014, -0.72465014, -0.724...
# 1557  [6.5335608, 6.5335608, 6.5335608, 6.5335608, 6...
# 1558  [-3.1225982, -3.1225982, -3.1225982, -3.122598...
# 1559  [0.32385036, 0.32385036, 0.32385036, 0.3238503...
#
# [1560 rows x 7 columns]

# %%
mfcc_parameters = []
for iteration, value in enumerate(df["mfcc"]):
    mfcc_stack = []
    for i in range(0,12):
        data_stack = np.hstack((np.mean(df["mfcc"][iteration][i]), 
                    np.std(df["mfcc"][iteration][i]), 
                    np.median(df["mfcc"][iteration][i]), 
                    np.percentile(df["mfcc"][iteration][i], 25), 
                    np.percentile(df["mfcc"][iteration][i], 75), 
                    scipy.stats.iqr(df["mfcc"][iteration][i], rng=(10, 90)),
                    scipy.stats.kurtosis(df["mfcc"][iteration][i]),
                    scipy.stats.skew(df["mfcc"][iteration][i]),
                    np.min(df["mfcc"][iteration][i]),
                    np.max(df["mfcc"][iteration][i])
                    ))
        mfcc_stack = np.hstack((mfcc_stack, data_stack))
    mfcc_parameters.append(mfcc_stack)

df["mfcc_parameters"] = mfcc_parameters

# %%
display(df)
# Out:
#                       file_name  \
# 0         [cel][cla]0001__1.wav
# 1         [cel][cla]0001__2.wav
# 2         [cel][cla]0001__3.wav
# 3         [cel][cla]0002__1.wav
# 4         [cel][cla]0002__2.wav
# ...                         ...
# 1555  [voi][pop_roc]2546__3.wav
# 1556  [voi][pop_roc]2547__1.wav
# 1557  [voi][pop_roc]2547__2.wav
# 1558  [voi][pop_roc]2547__3.wav
# 1559  [voi][pop_roc]2548__1.wav
#
#                                               file_data  sampling_frequency  \
# 0     [0.022232056, 0.02468872, 0.02645874, 0.027236...               44100
# 1     [-0.0033721924, -0.003967285, -0.003479004, -0...               44100
# 2     [0.00061035156, 0.0001373291, -0.0005950928, -...               44100
# 3     [-0.00024414062, -0.0013885498, -0.0026397705,...               44100
# 4     [-0.00018310547, 0.00076293945, 0.0011901855, ...               44100
# ...                                                 ...                 ...
# 1555  [0.0059509277, 0.015350342, 0.023391724, 0.032...               44100
# 1556  [-0.11528015, -0.15473938, -0.15000916, -0.113...               44100
# 1557  [0.1661377, 0.15690613, 0.12338257, 0.07142639...               44100
# 1558  [0.14439392, 0.12376404, 0.10206604, 0.0853881...               44100
# 1559  [0.009460449, -0.008239746, -0.022598267, -0.0...               44100
#
#       label                                               mfcc  \
# 0         0  [-452.01215, -463.70468, -473.78613, -472.0447...
# 1         0  [-353.5875, -345.70627, -341.9458, -340.2455, ...
# 2         0  [-426.93094, -434.9382, -442.07135, -440.38293...
# 3         0  [-465.59283, -472.84494, -483.94357, -485.5826...
# 4         0  [-464.96738, -462.2898, -464.4726, -464.46667,...
# ...     ...                                                ...
# 1555     10  [-178.58676, -172.2699, -171.96695, -177.94272...
# 1556     10  [-127.25734, -122.60771, -121.361145, -122.555...
# 1557     10  [-134.16048, -133.197, -144.1307, -150.18326, ...
# 1558     10  [-119.69623, -61.883232, -53.847103, -72.93917...
# 1559     10  [-133.41035, -132.13742, -129.30109, -133.6045...
#
#                                              mfcc_delta  \
# 0     [-1.9220424, -1.9220424, -1.9220424, -1.922042...
# 1     [1.5634588, 1.5634588, 1.5634588, 1.5634588, 1...
# 2     [0.46890718, 0.46890718, 0.46890718, 0.4689071...
# 3     [-0.92114764, -0.92114764, -0.92114764, -0.921...
# 4     [-0.2734192, -0.2734192, -0.2734192, -0.273419...
# ...                                                 ...
# 1555  [-3.9553516, -3.9553516, -3.9553516, -3.955351...
# 1556  [-1.1543529, -1.1543529, -1.1543529, -1.154352...
# 1557  [11.054637, 11.054637, 11.054637, 11.054637, 1...
# 1558  [-2.1233065, -2.1233065, -2.1233065, -2.123306...
# 1559  [-0.738473, -0.738473, -0.738473, -0.738473, -...
#
#                                           mfcc_delta_sq  \
# 0     [0.7014014, 0.7014014, 0.7014014, 0.7014014, 0...
# 1     [-1.1336648, -1.1336648, -1.1336648, -1.133664...
# 2     [1.7306954, 1.7306954, 1.7306954, 1.7306954, 1...
# 3     [1.5679516, 1.5679516, 1.5679516, 1.5679516, 1...
# 4     [-0.3988473, -0.3988473, -0.3988473, -0.398847...
# ...                                                 ...
# 1555  [-1.0631608, -1.0631608, -1.0631608, -1.063160...
# 1556  [-0.72465014, -0.72465014, -0.72465014, -0.724...
# 1557  [6.5335608, 6.5335608, 6.5335608, 6.5335608, 6...
# 1558  [-3.1225982, -3.1225982, -3.1225982, -3.122598...
# 1559  [0.32385036, 0.32385036, 0.32385036, 0.3238503...
#
#                                         mfcc_parameters
# 0     [-452.01214599609375, 0.0, -452.01214599609375...
# 1     [-353.5874938964844, 0.0, -353.5874938964844, ...
# 2     [-426.9309387207031, 0.0, -426.9309387207031, ...
# 3     [-465.59283447265625, 0.0, -465.59283447265625...
# 4     [-464.9673767089844, 0.0, -464.9673767089844, ...
# ...                                                 ...
# 1555  [-178.58676147460938, 0.0, -178.58676147460938...
# 1556  [-127.25733947753906, 0.0, -127.25733947753906...
# 1557  [-134.1604766845703, 0.0, -134.1604766845703, ...
# 1558  [-119.69622802734375, 0.0, -119.69622802734375...
# 1559  [-133.4103546142578, 0.0, -133.4103546142578, ...
#
# [1560 rows x 8 columns]

# %%
# Standardizing Data

X_train, X_test, y_train, y_test = train_test_split(df['mfcc'].to_list(), df['label'].to_list(), test_size=0.2, random_state=42, stratify=df['label'].to_list())

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ## 2. Klasyfikacja
#
# Przeprowadzenie klasyfikacji za pomocą wektorów nośnych (Support Vector Machine) i optymalizacja hiperparametrów za pomocą Optuna

# %%
# Initial classification without optimizing hyperparameters

SVM = SVC(random_state=42)

SVM.fit(X_train_scaled, y_train)

SVM_test_preds = SVM.predict(X_test_scaled)
print('test recall = ', recall_score(y_test, SVM_test_preds, average='macro'))
print('test precision = ', precision_score(y_test, SVM_test_preds, average='macro'))
print('test accuracy = ', accuracy_score(y_test, SVM_test_preds))
print('test F1 = ', f1_score(y_test, SVM_test_preds, average='macro'))

print(confusion_matrix(y_test, SVM_test_preds))
# Out:
# test recall =  0.4213453213453214
# test precision =  0.4636847760224384
# test accuracy =  0.42948717948717946
# test F1 =  0.4239136661036161
# [[14  1  3  3  2  1  2  0  1  1  2]
#  [ 2  4  6  3  2  1  1  0  2  3  2]
#  [ 3  1 18  1  1  2  3  0  0  0  1]
#  [ 3  1  0 15  1  2  4  0  1  0  3]
#  [ 0  0  0  3  9  4  0  0  0  6  6]
#  [ 4  2  0  2  4 12  1  0  1  0  4]
#  [ 1  0  1  4  2  2 11  1  0  1  5]
#  [ 1  0  4  1  2  0  3  6  1  2  0]
#  [ 4  1  0  0  0  3  1  1 15  1  4]
#  [ 2  0  1  1  5  0  1  0  0 14  6]
#  [ 2  0  0  2  5  3  0  0  0  2 16]]

# %%
# Optimizing hyperparameters

scoring = {'f1_macro': make_scorer(f1_score, average='macro')}

# %%
def objective(trial, model, get_space, X, y):
    model_space = get_space(trial)

    mdl = model(**model_space)
    scores = cross_validate(mdl, X, y, scoring=scoring, cv=StratifiedKFold(n_splits=5), return_train_score=True)

    return np.mean(scores['test_f1_macro'])

# %%
model = SVC

def get_space(trial): 
    space = {"C": trial.suggest_uniform("C", 0, 25), 
           'kernel': trial.suggest_categorical("kernel",['linear', 'poly','sigmoid','rbf']),
           "degree": trial.suggest_int('degree', 2, 10),
            'gamma': trial.suggest_categorical('gamma', ['scale','auto']),
            'coef0': trial.suggest_uniform('coef0',-10,10),
            'shrinking': trial.suggest_categorical('shrinking',[True,False])}
    return space

trials = 50

# %%
study = optuna.create_study(direction='maximize')
study.optimize(lambda x: objective(x, model, get_space, X_train_scaled, y_train), n_trials=trials)

print('params: ', study.best_params)
# Out:
# [I 2023-01-09 23:54:08,658] A new study created in memory with name: no-name-318f6d87-940d-4279-9753-c20dbfa4ad44
# [I 2023-01-09 23:54:36,178] Trial 0 finished with value: 0.07794697620711 and parameters: {'C': 23.33299644101683, 'kernel': 'sigmoid', 'degree': 3, 'gamma': 'auto', 'coef0': -5.003086872629923, 'shrinking': True}. Best is trial 0 with value: 0.07794697620711.
# [I 2023-01-09 23:54:58,416] Trial 1 finished with value: 0.3504816984381666 and parameters: {'C': 0.25058562209055446, 'kernel': 'poly', 'degree': 2, 'gamma': 'auto', 'coef0': 6.738452321045582, 'shrinking': False}. Best is trial 1 with value: 0.3504816984381666.
# [I 2023-01-09 23:55:21,284] Trial 2 finished with value: 0.4400861074712689 and parameters: {'C': 3.910946914014529, 'kernel': 'poly', 'degree': 9, 'gamma': 'auto', 'coef0': 6.489149050754882, 'shrinking': False}. Best is trial 2 with value: 0.4400861074712689.
# [I 2023-01-09 23:55:46,137] Trial 3 finished with value: 0.37397554534125266 and parameters: {'C': 7.636722986149821, 'kernel': 'poly', 'degree': 4, 'gamma': 'auto', 'coef0': 8.134055754648823, 'shrinking': True}. Best is trial 2 with value: 0.4400861074712689.
# [I 2023-01-09 23:56:10,584] Trial 4 finished with value: 0.2809516335665509 and parameters: {'C': 24.185696121405318, 'kernel': 'linear', 'degree': 7, 'gamma': 'scale', 'coef0': 1.8538092601966145, 'shrinking': True}. Best is trial 2 with value: 0.4400861074712689.
# [I 2023-01-09 23:56:38,895] Trial 5 finished with value: 0.2809516335665509 and parameters: {'C': 2.9494734574575467, 'kernel': 'linear', 'degree': 4, 'gamma': 'auto', 'coef0': -2.8631253103516308, 'shrinking': True}. Best is trial 2 with value: 0.4400861074712689.
# [I 2023-01-09 23:57:06,061] Trial 6 finished with value: 0.060487047132423435 and parameters: {'C': 13.284781943115801, 'kernel': 'sigmoid', 'degree': 10, 'gamma': 'auto', 'coef0': -7.325804290110732, 'shrinking': False}. Best is trial 2 with value: 0.4400861074712689.
# [I 2023-01-09 23:57:38,528] Trial 7 finished with value: 0.48090848354176535 and parameters: {'C': 10.083767984933836, 'kernel': 'rbf', 'degree': 2, 'gamma': 'auto', 'coef0': -0.45106222891602954, 'shrinking': True}. Best is trial 7 with value: 0.48090848354176535.
# [I 2023-01-09 23:58:08,843] Trial 8 finished with value: 0.48090848354176535 and parameters: {'C': 20.0521786722581, 'kernel': 'rbf', 'degree': 4, 'gamma': 'auto', 'coef0': -8.94611917479926, 'shrinking': False}. Best is trial 7 with value: 0.48090848354176535.
# [I 2023-01-09 23:58:40,554] Trial 9 finished with value: 0.48090848354176535 and parameters: {'C': 13.795510101336703, 'kernel': 'rbf', 'degree': 6, 'gamma': 'auto', 'coef0': 1.934836096251729, 'shrinking': True}. Best is trial 7 with value: 0.48090848354176535.
# [I 2023-01-09 23:59:14,073] Trial 10 finished with value: 0.48090848354176535 and parameters: {'C': 10.148978016298884, 'kernel': 'rbf', 'degree': 2, 'gamma': 'scale', 'coef0': -1.4762957535589445, 'shrinking': True}. Best is trial 7 with value: 0.48090848354176535.
# [I 2023-01-09 23:59:44,771] Trial 11 finished with value: 0.48090848354176535 and parameters: {'C': 18.761037733692277, 'kernel': 'rbf', 'degree': 4, 'gamma': 'auto', 'coef0': -9.167732456110114, 'shrinking': False}. Best is trial 7 with value: 0.48090848354176535.
# [I 2023-01-10 00:00:15,149] Trial 12 finished with value: 0.48090848354176535 and parameters: {'C': 17.774975541305178, 'kernel': 'rbf', 'degree': 2, 'gamma': 'auto', 'coef0': -5.420553315884504, 'shrinking': False}. Best is trial 7 with value: 0.48090848354176535.
# [I 2023-01-10 00:00:46,100] Trial 13 finished with value: 0.48090848354176535 and parameters: {'C': 17.78233968495764, 'kernel': 'rbf', 'degree': 5, 'gamma': 'scale', 'coef0': -9.772832393654948, 'shrinking': False}. Best is trial 7 with value: 0.48090848354176535.
# [I 2023-01-10 00:01:17,810] Trial 14 finished with value: 0.48090848354176535 and parameters: {'C': 9.049271200750217, 'kernel': 'rbf', 'degree': 7, 'gamma': 'auto', 'coef0': 3.7778195893553965, 'shrinking': False}. Best is trial 7 with value: 0.48090848354176535.
# [I 2023-01-10 00:01:49,167] Trial 15 finished with value: 0.48090848354176535 and parameters: {'C': 21.32535742989969, 'kernel': 'rbf', 'degree': 3, 'gamma': 'auto', 'coef0': -2.8889398855860873, 'shrinking': True}. Best is trial 7 with value: 0.48090848354176535.
# [I 2023-01-10 00:02:19,305] Trial 16 finished with value: 0.48090848354176535 and parameters: {'C': 15.647707820054851, 'kernel': 'rbf', 'degree': 3, 'gamma': 'auto', 'coef0': 0.15061767671502224, 'shrinking': True}. Best is trial 7 with value: 0.48090848354176535.
# [I 2023-01-10 00:02:40,410] Trial 17 finished with value: 0.2809516335665509 and parameters: {'C': 6.771327442958204, 'kernel': 'linear', 'degree': 8, 'gamma': 'scale', 'coef0': 4.311640175212578, 'shrinking': False}. Best is trial 7 with value: 0.48090848354176535.
# [I 2023-01-10 00:03:06,145] Trial 18 finished with value: 0.12835367802669057 and parameters: {'C': 21.300719488682624, 'kernel': 'sigmoid', 'degree': 5, 'gamma': 'auto', 'coef0': -4.264648684274609, 'shrinking': True}. Best is trial 7 with value: 0.48090848354176535.
# [I 2023-01-10 00:03:36,345] Trial 19 finished with value: 0.48090848354176535 and parameters: {'C': 15.435121508843583, 'kernel': 'rbf', 'degree': 6, 'gamma': 'auto', 'coef0': 1.4156389594276062, 'shrinking': True}. Best is trial 7 with value: 0.48090848354176535.
# [I 2023-01-10 00:04:06,576] Trial 20 finished with value: 0.48090848354176535 and parameters: {'C': 14.157847205678447, 'kernel': 'rbf', 'degree': 6, 'gamma': 'auto', 'coef0': 9.893411239441713, 'shrinking': True}. Best is trial 7 with value: 0.48090848354176535.
# [I 2023-01-10 00:04:36,870] Trial 21 finished with value: 0.48090848354176535 and parameters: {'C': 11.541592275935361, 'kernel': 'rbf', 'degree': 3, 'gamma': 'scale', 'coef0': -1.2211245478352422, 'shrinking': True}. Best is trial 7 with value: 0.48090848354176535.
# [I 2023-01-10 00:05:07,183] Trial 22 finished with value: 0.48090848354176535 and parameters: {'C': 15.711255825893572, 'kernel': 'rbf', 'degree': 5, 'gamma': 'scale', 'coef0': 1.1568004403613157, 'shrinking': True}. Best is trial 7 with value: 0.48090848354176535.
# [I 2023-01-10 00:05:37,476] Trial 23 finished with value: 0.48090848354176535 and parameters: {'C': 17.033173130027443, 'kernel': 'rbf', 'degree': 6, 'gamma': 'auto', 'coef0': 9.503580274960633, 'shrinking': True}. Best is trial 7 with value: 0.48090848354176535.
# [I 2023-01-10 00:06:06,082] Trial 24 finished with value: 0.48090848354176535 and parameters: {'C': 11.692900386198204, 'kernel': 'rbf', 'degree': 4, 'gamma': 'scale', 'coef0': -7.161937415584713, 'shrinking': False}. Best is trial 7 with value: 0.48090848354176535.
# [I 2023-01-10 00:06:36,483] Trial 25 finished with value: 0.48090848354176535 and parameters: {'C': 11.890691514373602, 'kernel': 'rbf', 'degree': 3, 'gamma': 'scale', 'coef0': -5.713291024894092, 'shrinking': True}. Best is trial 7 with value: 0.48090848354176535.
# [I 2023-01-10 00:07:05,162] Trial 26 finished with value: 0.48090848354176535 and parameters: {'C': 17.122221915381225, 'kernel': 'rbf', 'degree': 7, 'gamma': 'scale', 'coef0': 8.587198422765297, 'shrinking': False}. Best is trial 7 with value: 0.48090848354176535.
# [I 2023-01-10 00:07:26,245] Trial 27 finished with value: 0.2809516335665509 and parameters: {'C': 19.137404023556854, 'kernel': 'linear', 'degree': 5, 'gamma': 'scale', 'coef0': -7.890632279790467, 'shrinking': False}. Best is trial 7 with value: 0.48090848354176535.
# [I 2023-01-10 00:07:56,525] Trial 28 finished with value: 0.48090848354176535 and parameters: {'C': 15.56674803245047, 'kernel': 'rbf', 'degree': 5, 'gamma': 'scale', 'coef0': 4.0477170987919955, 'shrinking': True}. Best is trial 7 with value: 0.48090848354176535.
# [I 2023-01-10 00:08:23,361] Trial 29 finished with value: 0.1351212610136578 and parameters: {'C': 8.030846093190783, 'kernel': 'sigmoid', 'degree': 8, 'gamma': 'scale', 'coef0': 3.9943346008317295, 'shrinking': False}. Best is trial 7 with value: 0.48090848354176535.
# [I 2023-01-10 00:08:46,924] Trial 30 finished with value: 0.435716544537543 and parameters: {'C': 22.155126567013923, 'kernel': 'poly', 'degree': 7, 'gamma': 'auto', 'coef0': 5.390026703846307, 'shrinking': True}. Best is trial 7 with value: 0.48090848354176535.
# [I 2023-01-10 00:09:18,226] Trial 31 finished with value: 0.48090848354176535 and parameters: {'C': 14.980942642689843, 'kernel': 'rbf', 'degree': 3, 'gamma': 'scale', 'coef0': -2.081497858267171, 'shrinking': True}. Best is trial 7 with value: 0.48090848354176535.
# [I 2023-01-10 00:09:49,022] Trial 32 finished with value: 0.48090848354176535 and parameters: {'C': 22.49713646147131, 'kernel': 'rbf', 'degree': 8, 'gamma': 'scale', 'coef0': -4.734144964759686, 'shrinking': True}. Best is trial 7 with value: 0.48090848354176535.
# [I 2023-01-10 00:10:19,791] Trial 33 finished with value: 0.48090848354176535 and parameters: {'C': 16.898681474238924, 'kernel': 'rbf', 'degree': 3, 'gamma': 'scale', 'coef0': 8.002914689721635, 'shrinking': True}. Best is trial 7 with value: 0.48090848354176535.
# [I 2023-01-10 00:10:44,292] Trial 34 finished with value: 0.439867772202707 and parameters: {'C': 15.076731621564285, 'kernel': 'poly', 'degree': 7, 'gamma': 'scale', 'coef0': 3.124266655833432, 'shrinking': True}. Best is trial 7 with value: 0.48090848354176535.
# [I 2023-01-10 00:11:15,364] Trial 35 finished with value: 0.48090848354176535 and parameters: {'C': 12.70212129291658, 'kernel': 'rbf', 'degree': 5, 'gamma': 'scale', 'coef0': -7.196645718301497, 'shrinking': False}. Best is trial 7 with value: 0.48090848354176535.
# [I 2023-01-10 00:11:45,143] Trial 36 finished with value: 0.48090848354176535 and parameters: {'C': 12.218586723928658, 'kernel': 'rbf', 'degree': 4, 'gamma': 'scale', 'coef0': -6.564111903194709, 'shrinking': False}. Best is trial 7 with value: 0.48090848354176535.
# [I 2023-01-10 00:12:12,886] Trial 37 finished with value: 0.13516328908057942 and parameters: {'C': 14.10317231246258, 'kernel': 'sigmoid', 'degree': 4, 'gamma': 'scale', 'coef0': 5.615524688503695, 'shrinking': False}. Best is trial 7 with value: 0.48090848354176535.
# [I 2023-01-10 00:12:35,204] Trial 38 finished with value: 0.2809516335665509 and parameters: {'C': 9.576882657958375, 'kernel': 'linear', 'degree': 9, 'gamma': 'scale', 'coef0': 7.943661482471843, 'shrinking': False}. Best is trial 7 with value: 0.48090848354176535.
# [I 2023-01-10 00:12:56,147] Trial 39 finished with value: 0.005797179530042556 and parameters: {'C': 11.359536661292292, 'kernel': 'poly', 'degree': 6, 'gamma': 'scale', 'coef0': -5.9038669658262455, 'shrinking': False}. Best is trial 7 with value: 0.48090848354176535.
# [I 2023-01-10 00:13:28,046] Trial 40 finished with value: 0.48090848354176535 and parameters: {'C': 23.986890288230228, 'kernel': 'rbf', 'degree': 10, 'gamma': 'scale', 'coef0': -3.70197853295182, 'shrinking': True}. Best is trial 7 with value: 0.48090848354176535.
# [I 2023-01-10 00:14:00,327] Trial 41 finished with value: 0.48090848354176535 and parameters: {'C': 12.996849963689339, 'kernel': 'rbf', 'degree': 8, 'gamma': 'scale', 'coef0': -7.935060909134028, 'shrinking': True}. Best is trial 7 with value: 0.48090848354176535.
# [I 2023-01-10 00:14:32,847] Trial 42 finished with value: 0.47910187110851954 and parameters: {'C': 5.776347224561661, 'kernel': 'rbf', 'degree': 9, 'gamma': 'scale', 'coef0': -6.2740941870864, 'shrinking': True}. Best is trial 7 with value: 0.48090848354176535.
# [I 2023-01-10 00:15:05,759] Trial 43 finished with value: 0.48090848354176535 and parameters: {'C': 13.136206362870498, 'kernel': 'rbf', 'degree': 6, 'gamma': 'auto', 'coef0': 9.507145925530391, 'shrinking': True}. Best is trial 7 with value: 0.48090848354176535.
# [I 2023-01-10 00:15:37,208] Trial 44 finished with value: 0.450644259333865 and parameters: {'C': 1.8056531000749008, 'kernel': 'rbf', 'degree': 10, 'gamma': 'scale', 'coef0': -3.5584555684027204, 'shrinking': False}. Best is trial 7 with value: 0.48090848354176535.
# [I 2023-01-10 00:16:08,600] Trial 45 finished with value: 0.48090848354176535 and parameters: {'C': 10.649708471040583, 'kernel': 'rbf', 'degree': 5, 'gamma': 'auto', 'coef0': 9.77964252356518, 'shrinking': True}. Best is trial 7 with value: 0.48090848354176535.
# [I 2023-01-10 00:16:41,836] Trial 46 finished with value: 0.48090848354176535 and parameters: {'C': 11.940853627828035, 'kernel': 'rbf', 'degree': 4, 'gamma': 'scale', 'coef0': -0.0632983125278115, 'shrinking': True}. Best is trial 7 with value: 0.48090848354176535.
# [I 2023-01-10 00:17:15,394] Trial 47 finished with value: 0.48090848354176535 and parameters: {'C': 10.68997073640298, 'kernel': 'rbf', 'degree': 5, 'gamma': 'auto', 'coef0': 9.25289155226284, 'shrinking': True}. Best is trial 7 with value: 0.48090848354176535.
# [I 2023-01-10 00:17:47,440] Trial 48 finished with value: 0.48090848354176535 and parameters: {'C': 8.536373398190086, 'kernel': 'rbf', 'degree': 4, 'gamma': 'scale', 'coef0': -0.4810878930628545, 'shrinking': True}. Best is trial 7 with value: 0.48090848354176535.
# [I 2023-01-10 00:18:20,318] Trial 49 finished with value: 0.48090848354176535 and parameters: {'C': 6.8093678501349455, 'kernel': 'rbf', 'degree': 5, 'gamma': 'auto', 'coef0': 6.6712226194281365, 'shrinking': True}. Best is trial 7 with value: 0.48090848354176535.
# params:  {'C': 10.083767984933836, 'kernel': 'rbf', 'degree': 2, 'gamma': 'auto', 'coef0': -0.45106222891602954, 'shrinking': True}

# %%
# Classification with optimized hyperparameters

SVM = SVC(C=10.083767984933836, kernel='rbf',gamma='auto',random_state=42, coef0=-0.45106222891602954, shrinking=True)

SVM.fit(X_train_scaled, y_train)

SVM_test_preds = SVM.predict(X_test_scaled)

# %%
print('test recall = ', recall_score(y_test, SVM_test_preds, average='macro'))
print('test precision = ', precision_score(y_test, SVM_test_preds, average='macro'))
print('test accuracy = ', accuracy_score(y_test, SVM_test_preds))
print('test F1 = ', f1_score(y_test, SVM_test_preds, average='macro'))

print(confusion_matrix(y_test, SVM_test_preds))
# Out:
# test recall =  0.44027639027639026
# test precision =  0.44703866318286384
# test accuracy =  0.44551282051282054
# test F1 =  0.43988739551637734
# [[19  1  4  2  1  1  1  0  0  1  0]
#  [ 2  7  5  1  2  2  0  1  3  3  0]
#  [ 3  2 16  2  0  1  2  1  2  0  1]
#  [ 1  2  2 16  2  0  3  0  2  0  2]
#  [ 0  2  0  1  8  5  0  0  1  6  5]
#  [ 3  2  1  1  4 13  1  0  1  1  3]
#  [ 1  1  1  6  1  1  9  3  1  0  4]
#  [ 2  0  2  1  1  0  3  8  1  2  0]
#  [ 3  1  0  1  0  1  1  2 18  0  3]
#  [ 3  0  1  1  3  0  2  0  0 14  6]
#  [ 2  0  0  3  7  4  0  0  0  3 11]]
